# %%
import numpy
from matplotlib import pyplot
from data_discovery.ocean_integration import OceanIntegration

# %%
infura_url = "https://mainnet.infura.io/v3/334badec8bd2402e8e60e8424698981b"

metadata_cache_url = "https://v4.aquarius.oceanprotocol.com"
ocean_integration = OceanIntegration(infura_url, metadata_cache_url)

ocean_instance = ocean_integration.get_ocean_instance(
        infura_url,
    )

# %%
ddo_2 = {
  "@context": ["https://w3id.org/did/v1"],
  "id": "did:op:ACce67694eD2848dd683c651Dab7Af823b7dd123",
  "version": "4.1.0",
  "chainId": 1,
  "nftAddress": "0x123",
  "metadata": {
    "created": "2020-11-15T12:27:48Z",
    "updated": "2021-05-17T21:58:02Z",
    "description": "Sample description",
    "name": "Sample asset",
    "type": "dataset",
    "author": "OPF",
    "license": "https://market.oceanprotocol.com/terms"
  },
  "services": [
    {
      "id": "1",
      "type": "access",
      "files": "...",
      "name": "Download service",
      "description": "Download service",
      "datatokenAddress": "0x123",
      "serviceEndpoint": "https://myprovider.com",
      "timeout": 0,
      "consumerParameters": [
        {
          "name": "surname",
          "type": "text",
          "label": "Name",
          "required": True,
          "default": "NoName",
          "description": "Please fill your name"
        },
        {
          "name": "age",
          "type": "number",
          "label": "Age",
          "required": False,
          "default": 0,
          "description": "Please fill your age"
        }
      ]
    },
    {
      "id": "2",
      "type": "compute",
      "files": "...",
      "name": "Compute service",
      "description": "Compute service",
      "datatokenAddress": "0x124",
      "serviceEndpoint": "https://myprovider.com",
      "timeout": 3600,
      "compute": {
        "allowRawAlgorithm": False,
        "allowNetworkAccess": True,
        "publisherTrustedAlgorithmPublishers": ["0x234", "0x235"],
        "publisherTrustedAlgorithms": [
          {
            "did": "did:op:123",
            "filesChecksum": "100",
            "containerSectionChecksum": "200"
          },
          {
            "did": "did:op:124",
            "filesChecksum": "110",
            "containerSectionChecksum": "210"
          }
        ]
      }
    }
  ],
  "credentials": {
    "allow": [
      {
        "type": "address",
        "values": ["0x123", "0x456"]
      }
    ],
    "deny": [
      {
        "type": "address",
        "values": ["0x2222", "0x333"]
      }
    ]
  },

  "nft": {
    "address": "0x123",
    "name": "Ocean Protocol Asset",
    "symbol": "OCEAN-A",
    "owner": "0x0000000",
    "state": 0,
    "created": "2000-10-31T01:30:00",
    "tokenURI": "xxx"
  },

  "datatokens": [
    {
      "address": "0x000000",
      "name": "Datatoken 1",
      "symbol": "DT-1",
      "serviceId": "1"
    },
    {
      "address": "0x000001",
      "name": "Datatoken 2",
      "symbol": "DT-2",
      "serviceId": "2"
    }
  ],

  "event": {
    "tx": "0x8d127de58509be5dfac600792ad24cc9164921571d168bff2f123c7f1cb4b11c",
    "block": 12831214,
    "from": "0xAcca11dbeD4F863Bb3bC2336D3CE5BAC52aa1f83",
    "contract": "0x1a4b70d8c9DcA47cD6D0Fb3c52BB8634CA1C0Fdf",
    "datetime": "2000-10-31T01:30:00"
  },

  "purgatory": {
    "state": False
  },

  "stats": {
    "orders": 4
  }
}

# %%
ddo = {
    "@context": [
        "https://w3id.org/did/v1"
    ],
    "chainId": 137,
    "datatokens": [
        {
            "address": "0xb4F96a2022DDe55Da5faDb2fBEe62Fc60C4D10f3",
            "name": "Tactful Prawn Token",
            "serviceId": "2a506b893060a4a59ceb46f6b7af82bc7faa6d008dfbef8e522905a4620e3a13",
            "symbol": "TACPRA-82"
        }
    ],
    "event": {
        "block": 39483923,
        "contract": "0xE00a11915fd22864445051626e52d6E97dD10a6f",
        "datetime": "2023-02-19T21:01:29",
        "from": "0x28f39Db34bd36ba5dC9009015f67A57F90748422",
        "tx": "0x88ad8872d003f68b8fad5b8f24d1d447068bd1be4d83eb893dda98ad6be836e1"
    },
    "id": "did:op:4d8f687960fe402a396706bd12203fa8be9d2ac74e2573ba3ac7926d6695458d",
    "metadata": {
        "additionalInformation": {
            "termsAndConditions": True
        },
        "author": "vonder3Dprint",
        "created": "2023-02-17T22:04:11Z",
        "description": "You'll find my stl files of a CAD model I made to have the extruder on a fixed place on your 3D printer (can be used on any printer using 4020 profile).\nYou'll also find the instructions for the assembly.\n\nI'll will soon add my print settings for PETG PLA and ABS with some results and improvements.\nThose settings will be updated as soon as I find some nice improvements.\n",
        "license": "https://market.oceanprotocol.com/terms",
        "links": [
            "https://drive.proton.me/urls/5YPRVB7E68#FkbtULpvQCbY"
        ],
        "name": "STL files of an extruder support for 3D printer",
        "tags": [
            "3d-printing"
        ],
        "type": "dataset",
        "updated": "2023-02-17T22:04:11Z"
    },
    "nft": {
        "address": "0xE00a11915fd22864445051626e52d6E97dD10a6f",
        "created": "2023-02-17T22:04:30",
        "name": "Ocean Data NFT",
        "owner": "0x28f39Db34bd36ba5dC9009015f67A57F90748422",
        "state": 0,
        "symbol": "OCEAN-NFT",
        "tokenURI": "data:application/json;base64,..."
    },
    "nftAddress": "0xE00a11915fd22864445051626e52d6E97dD10a6f",
    "purgatory": {
        "state": False
    },
    "services": [
        {
            "datatokenAddress": "0xb4F96a2022DDe55Da5faDb2fBEe62Fc60C4D10f3",
            "files": "...",
            "id": "2a506b893060a4a59ceb46f6b7af82bc7faa6d008dfbef8e522905a4620e3a13",
            "serviceEndpoint": "https://v4.provider.polygon.oceanprotocol.com",
            "timeout": 86400,
            "type": "access"
        }
    ],
    "stats": {
        "allocated": 0,
        "orders": 11,
        "price": {
            "tokenAddress": "0x282d8efCe846A88B159800bd4130ad77443Fa1A1",
            "tokenSymbol": "mOCEAN",
            "value": 200
        }
    },
    "version": "4.1.0"
}

# %%
data_id = "did:op:622f5e7443c304ec240b093df6d902dc9f7118d8b81b1bf66b8b0ac395038d31"

data_ddo = ocean_instance.assets.resolve(data_id)

data_ddo

# %%
# data_id_2 = "did:op:ACce67694eD2848dd683c651Dab7Af823b7dd123"
data_ddo_2 = ocean_instance.assets.resolve(ddo_2['id'])

data_ddo_2

# %%
ERC_20_TOKEN_ADDRESS = "0xDc9cEE9f436339fF2d73bbb7Ba1A79715552290b"

INFURA_API_KEY = "334badec8bd2402e8e60e8424698981b"
SIGNER_PRIVATE_KEY = (
    "0x1894d9f5066fc976c46575ea43a854af2d26769a00310c1ad1c10f3b1cdb41a9"
)
rpc_url = "https://polygon-mumbai.infura.io/v3"
# Address = "0xdc9cee9f436339ff2d73bbb7ba1a79715552290b" # unChecksummed
Address = "0xDc9cEE9f436339fF2d73bbb7Ba1A79715552290b"

# %%
id = "did:op:ACce67694eD2848dd683c651Dab7Af823b7dd123"
ocean_instance.assets.resolve(id)

# %%
compute_service = ddo_2['services'][1]
compute_service
# Out:
# {'id': '2',
#  'type': 'compute',
#  'files': '...',
#  'name': 'Compute service',
#  'description': 'Compute service',
#  'datatokenAddress': '0x124',
#  'serviceEndpoint': 'https://myprovider.com',
#  'timeout': 3600,
#  'compute': {'allowRawAlgorithm': False,
#   'allowNetworkAccess': True,
#   'publisherTrustedAlgorithmPublishers': ['0x234', '0x235'],
#   'publisherTrustedAlgorithms': [{'did': 'did:op:123',
#     'filesChecksum': '100',
#     'containerSectionChecksum': '200'},
#    {'did': 'did:op:124',
#     'filesChecksum': '110',
#     'containerSectionChecksum': '210'}]}}

# %%
free_c2d_env = ocean_instance.compute.get_free_c2d_environment(compute_service['serviceEndpoint'],  ddo['chainId'])
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 free_c2d_env = ocean_instance.compute.get_free_c2d_environment(compute_service['serviceEndpoint'],  80001)
#
# File ~/DesightChallenges/desightsenv/lib/python3.10/site-packages/enforce_typing/decorator.py:29, in enforce_types.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#      26 @wraps(func)
#      27 def wrapper(*args, **kwargs):
#      28     check_types(*args, **kwargs)
# ---> 29     return func(*args, **kwargs)
#
# File ~/DesightChallenges/desightsenv/lib/python3.10/site-packages/ocean_lib/ocean/ocean_compute.py:155, in OceanCompute.get_free_c2d_environment(self, service_endpoint, chain_id)
#     152 @enforce_types
#     153 def get_free_c2d_environment(self, service_endpoint: str, chain_id) -> str:
#     154     environments = self.get_c2d_environments(service_endpoint, chain_id)
# ...

# %%
# Convenience variables
# DATA_did = DATA_ddo.did
# ALGO_did = ALGO_ddo.did

# Operate on updated and indexed assets
# DATA_ddo = ocean.assets.resolve(DATA_did)
# ALGO_ddo = ocean.assets.resolve(ALGO_did)


# algo_service = ALGO_ddo.services[0]

from datetime import datetime, timedelta, timezone
from ocean_lib.models.compute_input import ComputeInput

DATA_compute_input = ComputeInput(data_ddo, compute_service)
# ALGO_compute_input = ComputeInput(ALGO_ddo, algo_service)

# Pay for dataset and algo for 1 day
datasets, algorithm = ocean_instance.assets.pay_for_compute_service(
    datasets=[DATA_compute_input],
    # algorithm_data=ALGO_compute_input,
    consume_market_order_fee_address=Address,
    tx_dict={"from": "synthetIQ"},
    compute_environment=free_c2d_env["id"],
    valid_until=int((datetime.now(timezone.utc) + timedelta(days=1)).timestamp()),
    consumer_address=free_c2d_env["consumerAddress"],
)
assert datasets, "pay for dataset unsuccessful"
assert algorithm, "pay for algorithm unsuccessful"

# Start compute job
job_id = ocean_instance.compute.start(
    consumer_wallet=Address,
    dataset=datasets[0],
    compute_environment=free_c2d_env["id"],
    algorithm=algorithm,
)
print(f"Started compute job with id: {job_id}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 11
#       1 # Convenience variables
#       2 # DATA_did = DATA_ddo.did
#       3 # ALGO_did = ALGO_ddo.did
#    (...)
#       9
#      10 # algo_service = ALGO_ddo.services[0]
# ---> 11 free_c2d_env = ocean_instance.compute.get_free_c2d_environment(compute_service.service_endpoint, data_ddo.chain_id)
#      13 from datetime import datetime, timedelta, timezone
#      14 from ocean_lib.models.compute_input import ComputeInput
#
# AttributeError: 'dict' object has no attribute 'service_endpoint'

# %%
X0_vec = numpy.linspace(-5., 10., 15)
X1_vec = numpy.linspace(0., 15., 15)
X0, X1 = numpy.meshgrid(X0_vec, X1_vec)
b, c, t = 0.12918450914398066, 1.5915494309189535, 0.039788735772973836
u = X1 - b * X0 ** 2 + c * X0 - 6
r = 10. * (1. - t) * numpy.cos(X0) + 10
Z = u ** 2 + r

fig, ax = pyplot.subplots(subplot_kw={"projection": "3d"})
ax.scatter(X0, X1, model, c="r", label="model")
pyplot.title("Data + model")
pyplot.show()  # or pyplot.savefig("test.png") to save the plot as a .png file instead
